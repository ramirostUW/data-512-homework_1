# %% [markdown]
# # Step 2 - Organizing Data Using R
#
# This notebook is written to take the raw data obtained in the Step 1 Notebook (also in this folder) and stored in thousands of individual JSON Files, and compile it into just three JSON files. After running this Notebook fully, we will have three JSON files that contain the monthly view data between Jan 2015 and April 2023 for all Wikipedia articles on Academy Award-winning films. One of these will have all of the views for these articles from Desktops, one will have the data for views from mobile devices (representing the sum of mobile-app and mobile-web data as presented by the API), and one will have the sum of the views in the other two JSON files (the cumulative views).
#
# Unlike the Steps 1 and 3 Notebooks, which were written in Python, this Notebook uses R because the dplyr package's table operations make joins and aggregation fast, and are generally easier to use than Python's Pandas library. For information on running a Jupyter Notebook with an R kernel, please see [here](https://docs.anaconda.com/free/navigator/tutorials/r-lang/).

# %% [markdown]
# ## Taking in Raw Data
#
# The below two cells take in all of the JSON files produced by Step 1 and put them in three different

# %%
library(jsonlite)
library(dplyr)


##This function takes in a list of paths containing JSON files from 
##Pageview API calls and combines them into one R list. 
##The individual lists of calls stored in the original calls are placed
##in the list under a key that corresponds to their article name. 
compile_into_json <- function(list_of_json_files){
  big_json <- list()
  for (file_name in list_of_json_files){
    current_json <- read_json(path = file_name)[['items']]
    article_name <- current_json[[1]]$article
    big_json[article_name] <- list(current_json)
  }
  return(big_json)
}


##These lines scan the folders containing the view data
##for each access type and use the previous function
##to combine the data for each access type into one list. 
list_of_desktop_files <- paste0("raw_data/desktop/", list.files(path = "raw_data/desktop"))
desktop <- compile_into_json(list_of_desktop_files)


list_of_mob_app_files <- paste0("raw_data/mobile-app/", list.files(path = "raw_data/mobile-app"))
mob_app <- compile_into_json(list_of_mob_app_files)


list_of_mob_web_files <- paste0("raw_data/mobile-web/", list.files(path = "raw_data/mobile-web"))
mob_web <- compile_into_json(list_of_mob_web_files)
# Out:
# Attaching package: 'dplyr'
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
##quick sanity check to make sure all three compiled list objects 
##look correct
print("desktop:")
print(head(desktop))

print("mob_app:")
print(head(mob_app))

print("mob_web:")
print(head(mob_web))
# Out:
# [1] "desktop:"
# $`12_Years_a_Slave_(film)`
# $`12_Years_a_Slave_(film)`[[1]]
# $`12_Years_a_Slave_(film)`[[1]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[1]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[1]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[1]]$timestamp
# [1] "2015070100"
#
# $`12_Years_a_Slave_(film)`[[1]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[1]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[1]]$views
# [1] 62693
#
#
# $`12_Years_a_Slave_(film)`[[2]]
# $`12_Years_a_Slave_(film)`[[2]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[2]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[2]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[2]]$timestamp
# [1] "2015080100"
#
# $`12_Years_a_Slave_(film)`[[2]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[2]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[2]]$views
# [1] 58902
#
#
# $`12_Years_a_Slave_(film)`[[3]]
# $`12_Years_a_Slave_(film)`[[3]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[3]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[3]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[3]]$timestamp
# [1] "2015090100"
#
# $`12_Years_a_Slave_(film)`[[3]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[3]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[3]]$views
# [1] 59116
#
#
# $`12_Years_a_Slave_(film)`[[4]]
# $`12_Years_a_Slave_(film)`[[4]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[4]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[4]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[4]]$timestamp
# [1] "2015100100"
#
# $`12_Years_a_Slave_(film)`[[4]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[4]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[4]]$views
# [1] 65535
#
#
# $`12_Years_a_Slave_(film)`[[5]]
# $`12_Years_a_Slave_(film)`[[5]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[5]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[5]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[5]]$timestamp
# [1] "2015110100"
#
# $`12_Years_a_Slave_(film)`[[5]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[5]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[5]]$views
# [1] 66646
#
#
# $`12_Years_a_Slave_(film)`[[6]]
# $`12_Years_a_Slave_(film)`[[6]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[6]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[6]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[6]]$timestamp
# [1] "2015120100"
#
# $`12_Years_a_Slave_(film)`[[6]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[6]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[6]]$views
# [1] 71846
#
#
# $`12_Years_a_Slave_(film)`[[7]]
# $`12_Years_a_Slave_(film)`[[7]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[7]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[7]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[7]]$timestamp
# [1] "2016010100"
#
# $`12_Years_a_Slave_(film)`[[7]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[7]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[7]]$views
# [1] 91671
#
#
# $`12_Years_a_Slave_(film)`[[8]]
# $`12_Years_a_Slave_(film)`[[8]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[8]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[8]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[8]]$timestamp
# [1] "2016020100"
#
# $`12_Years_a_Slave_(film)`[[8]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[8]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[8]]$views
# [1] 86968
#
#
# $`12_Years_a_Slave_(film)`[[9]]
# $`12_Years_a_Slave_(film)`[[9]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[9]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[9]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[9]]$timestamp
# [1] "2016030100"
#
# $`12_Years_a_Slave_(film)`[[9]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[9]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[9]]$views
# [1] 67724
#
#
# $`12_Years_a_Slave_(film)`[[10]]
# $`12_Years_a_Slave_(film)`[[10]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[10]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[10]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[10]]$timestamp
# [1] "2016040100"
#
# $`12_Years_a_Slave_(film)`[[10]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[10]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[10]]$views
# [1] 55623
#
#
# $`12_Years_a_Slave_(film)`[[11]]
# $`12_Years_a_Slave_(film)`[[11]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[11]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[11]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[11]]$timestamp
# [1] "2016050100"
#
# $`12_Years_a_Slave_(film)`[[11]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[11]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[11]]$views
# [1] 61650
#
#
# $`12_Years_a_Slave_(film)`[[12]]
# $`12_Years_a_Slave_(film)`[[12]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[12]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[12]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[12]]$timestamp
# [1] "2016060100"
#
# $`12_Years_a_Slave_(film)`[[12]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[12]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[12]]$views
# [1] 64620
#
#
# $`12_Years_a_Slave_(film)`[[13]]
# $`12_Years_a_Slave_(film)`[[13]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[13]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[13]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[13]]$timestamp
# [1] "2016070100"
#
# $`12_Years_a_Slave_(film)`[[13]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[13]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[13]]$views
# [1] 45706
#
#
# $`12_Years_a_Slave_(film)`[[14]]
# $`12_Years_a_Slave_(film)`[[14]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[14]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[14]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[14]]$timestamp
# [1] "2016080100"
#
# $`12_Years_a_Slave_(film)`[[14]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[14]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[14]]$views
# [1] 44370
#
#
# $`12_Years_a_Slave_(film)`[[15]]
# $`12_Years_a_Slave_(film)`[[15]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[15]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[15]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[15]]$timestamp
# [1] "2016090100"
#
# $`12_Years_a_Slave_(film)`[[15]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[15]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[15]]$views
# [1] 55130
#
#
# $`12_Years_a_Slave_(film)`[[16]]
# $`12_Years_a_Slave_(film)`[[16]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[16]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[16]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[16]]$timestamp
# [1] "2016100100"
#
# $`12_Years_a_Slave_(film)`[[16]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[16]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[16]]$views
# [1] 62820
#
#
# $`12_Years_a_Slave_(film)`[[17]]
# $`12_Years_a_Slave_(film)`[[17]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[17]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[17]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[17]]$timestamp
# [1] "2016110100"
#
# $`12_Years_a_Slave_(film)`[[17]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[17]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[17]]$views
# [1] 67663
#
#
# $`12_Years_a_Slave_(film)`[[18]]
# $`12_Years_a_Slave_(film)`[[18]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[18]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[18]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[18]]$timestamp
# [1] "2016120100"
#
# $`12_Years_a_Slave_(film)`[[18]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[18]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[18]]$views
# [1] 58897
#
#
# $`12_Years_a_Slave_(film)`[[19]]
# $`12_Years_a_Slave_(film)`[[19]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[19]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[19]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[19]]$timestamp
# [1] "2017010100"
#
# $`12_Years_a_Slave_(film)`[[19]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[19]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[19]]$views
# [1] 64869
#
#
# $`12_Years_a_Slave_(film)`[[20]]
# $`12_Years_a_Slave_(film)`[[20]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[20]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[20]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[20]]$timestamp
# [1] "2017020100"
#
# $`12_Years_a_Slave_(film)`[[20]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[20]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[20]]$views
# [1] 69101
#
#
# $`12_Years_a_Slave_(film)`[[21]]
# $`12_Years_a_Slave_(film)`[[21]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[21]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[21]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[21]]$timestamp
# [1] "2017030100"
#
# $`12_Years_a_Slave_(film)`[[21]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[21]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[21]]$views
# [1] 58706
#
#
# $`12_Years_a_Slave_(film)`[[22]]
# $`12_Years_a_Slave_(film)`[[22]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[22]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[22]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[22]]$timestamp
# [1] "2017040100"
#
# $`12_Years_a_Slave_(film)`[[22]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[22]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[22]]$views
# [1] 45490
#
#
# $`12_Years_a_Slave_(film)`[[23]]
# $`12_Years_a_Slave_(film)`[[23]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[23]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[23]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[23]]$timestamp
# [1] "2017050100"
#
# $`12_Years_a_Slave_(film)`[[23]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[23]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[23]]$views
# [1] 49448
#
#
# $`12_Years_a_Slave_(film)`[[24]]
# $`12_Years_a_Slave_(film)`[[24]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[24]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[24]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[24]]$timestamp
# [1] "2017060100"
#
# $`12_Years_a_Slave_(film)`[[24]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[24]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[24]]$views
# [1] 38043
#
#
# $`12_Years_a_Slave_(film)`[[25]]
# $`12_Years_a_Slave_(film)`[[25]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[25]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[25]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[25]]$timestamp
# [1] "2017070100"
#
# $`12_Years_a_Slave_(film)`[[25]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[25]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[25]]$views
# [1] 37439
#
#
# $`12_Years_a_Slave_(film)`[[26]]
# $`12_Years_a_Slave_(film)`[[26]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[26]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[26]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[26]]$timestamp
# [1] "2017080100"
#
# $`12_Years_a_Slave_(film)`[[26]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[26]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[26]]$views
# [1] 33207
#
#
# $`12_Years_a_Slave_(film)`[[27]]
# $`12_Years_a_Slave_(film)`[[27]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[27]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[27]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[27]]$timestamp
# [1] "2017090100"
#
# $`12_Years_a_Slave_(film)`[[27]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[27]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[27]]$views
# [1] 36937
#
#
# $`12_Years_a_Slave_(film)`[[28]]
# $`12_Years_a_Slave_(film)`[[28]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[28]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[28]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[28]]$timestamp
# [1] "2017100100"
#
# $`12_Years_a_Slave_(film)`[[28]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[28]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[28]]$views
# [1] 42508
#
#
# $`12_Years_a_Slave_(film)`[[29]]
# $`12_Years_a_Slave_(film)`[[29]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[29]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[29]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[29]]$timestamp
# [1] "2017110100"
#
# $`12_Years_a_Slave_(film)`[[29]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[29]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[29]]$views
# [1] 47884
#
#
# $`12_Years_a_Slave_(film)`[[30]]
# $`12_Years_a_Slave_(film)`[[30]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[30]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[30]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[30]]$timestamp
# [1] "2017120100"
#
# $`12_Years_a_Slave_(film)`[[30]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[30]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[30]]$views
# [1] 39233
#
#
# $`12_Years_a_Slave_(film)`[[31]]
# $`12_Years_a_Slave_(film)`[[31]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[31]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[31]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[31]]$timestamp
# [1] "2018010100"
#
# $`12_Years_a_Slave_(film)`[[31]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[31]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[31]]$views
# [1] 45237
#
#
# $`12_Years_a_Slave_(film)`[[32]]
# $`12_Years_a_Slave_(film)`[[32]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[32]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[32]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[32]]$timestamp
# [1] "2018020100"
#
# $`12_Years_a_Slave_(film)`[[32]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[32]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[32]]$views
# [1] 59414
#
#
# $`12_Years_a_Slave_(film)`[[33]]
# $`12_Years_a_Slave_(film)`[[33]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[33]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[33]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[33]]$timestamp
# [1] "2018030100"
#
# $`12_Years_a_Slave_(film)`[[33]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[33]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[33]]$views
# [1] 63451
#
#
# $`12_Years_a_Slave_(film)`[[34]]
# $`12_Years_a_Slave_(film)`[[34]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[34]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[34]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[34]]$timestamp
# [1] "2018040100"
#
# $`12_Years_a_Slave_(film)`[[34]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[34]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[34]]$views
# [1] 41118
#
#
# $`12_Years_a_Slave_(film)`[[35]]
# $`12_Years_a_Slave_(film)`[[35]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[35]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[35]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[35]]$timestamp
# [1] "2018050100"
#
# $`12_Years_a_Slave_(film)`[[35]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[35]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[35]]$views
# [1] 40860
#
#
# $`12_Years_a_Slave_(film)`[[36]]
# $`12_Years_a_Slave_(film)`[[36]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[36]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[36]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[36]]$timestamp
# [1] "2018060100"
#
# $`12_Years_a_Slave_(film)`[[36]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[36]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[36]]$views
# [1] 30240
#
#
# $`12_Years_a_Slave_(film)`[[37]]
# $`12_Years_a_Slave_(film)`[[37]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[37]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[37]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[37]]$timestamp
# [1] "2018070100"
#
# $`12_Years_a_Slave_(film)`[[37]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[37]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[37]]$views
# [1] 27097
#
#
# $`12_Years_a_Slave_(film)`[[38]]
# $`12_Years_a_Slave_(film)`[[38]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[38]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[38]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[38]]$timestamp
# [1] "2018080100"
#
# $`12_Years_a_Slave_(film)`[[38]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[38]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[38]]$views
# [1] 28133
#
#
# $`12_Years_a_Slave_(film)`[[39]]
# $`12_Years_a_Slave_(film)`[[39]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[39]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[39]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[39]]$timestamp
# [1] "2018090100"
#
# $`12_Years_a_Slave_(film)`[[39]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[39]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[39]]$views
# [1] 28144
#
#
# $`12_Years_a_Slave_(film)`[[40]]
# $`12_Years_a_Slave_(film)`[[40]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[40]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[40]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[40]]$timestamp
# [1] "2018100100"
#
# $`12_Years_a_Slave_(film)`[[40]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[40]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[40]]$views
# [1] 32851
#
#
# $`12_Years_a_Slave_(film)`[[41]]
# $`12_Years_a_Slave_(film)`[[41]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[41]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[41]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[41]]$timestamp
# [1] "2018110100"
#
# $`12_Years_a_Slave_(film)`[[41]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[41]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[41]]$views
# [1] 41516
#
#
# $`12_Years_a_Slave_(film)`[[42]]
# $`12_Years_a_Slave_(film)`[[42]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[42]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[42]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[42]]$timestamp
# [1] "2018120100"
#
# $`12_Years_a_Slave_(film)`[[42]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[42]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[42]]$views
# [1] 32604
#
#
# $`12_Years_a_Slave_(film)`[[43]]
# $`12_Years_a_Slave_(film)`[[43]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[43]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[43]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[43]]$timestamp
# [1] "2019010100"
#
# $`12_Years_a_Slave_(film)`[[43]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[43]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[43]]$views
# [1] 35420
#
#
# $`12_Years_a_Slave_(film)`[[44]]
# $`12_Years_a_Slave_(film)`[[44]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[44]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[44]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[44]]$timestamp
# [1] "2019020100"
#
# $`12_Years_a_Slave_(film)`[[44]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[44]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[44]]$views
# [1] 38996
#
#
# $`12_Years_a_Slave_(film)`[[45]]
# $`12_Years_a_Slave_(film)`[[45]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[45]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[45]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[45]]$timestamp
# [1] "2019030100"
#
# $`12_Years_a_Slave_(film)`[[45]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[45]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[45]]$views
# [1] 44091
#
#
# $`12_Years_a_Slave_(film)`[[46]]
# $`12_Years_a_Slave_(film)`[[46]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[46]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[46]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[46]]$timestamp
# [1] "2019040100"
#
# $`12_Years_a_Slave_(film)`[[46]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[46]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[46]]$views
# [1] 31870
#
#
# $`12_Years_a_Slave_(film)`[[47]]
# $`12_Years_a_Slave_(film)`[[47]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[47]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[47]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[47]]$timestamp
# [1] "2019050100"
#
# $`12_Years_a_Slave_(film)`[[47]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[47]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[47]]$views
# [1] 26791
#
#
# $`12_Years_a_Slave_(film)`[[48]]
# $`12_Years_a_Slave_(film)`[[48]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[48]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[48]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[48]]$timestamp
# [1] "2019060100"
#
# $`12_Years_a_Slave_(film)`[[48]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[48]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[48]]$views
# [1] 22250
#
#
# $`12_Years_a_Slave_(film)`[[49]]
# $`12_Years_a_Slave_(film)`[[49]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[49]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[49]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[49]]$timestamp
# [1] "2019070100"
#
# $`12_Years_a_Slave_(film)`[[49]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[49]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[49]]$views
# [1] 27164
#
#
# $`12_Years_a_Slave_(film)`[[50]]
# $`12_Years_a_Slave_(film)`[[50]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[50]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[50]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[50]]$timestamp
# [1] "2019080100"
#
# $`12_Years_a_Slave_(film)`[[50]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[50]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[50]]$views
# [1] 25730
#
#
# $`12_Years_a_Slave_(film)`[[51]]
# $`12_Years_a_Slave_(film)`[[51]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[51]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[51]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[51]]$timestamp
# [1] "2019090100"
#
# $`12_Years_a_Slave_(film)`[[51]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[51]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[51]]$views
# [1] 29597
#
#
# $`12_Years_a_Slave_(film)`[[52]]
# $`12_Years_a_Slave_(film)`[[52]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[52]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[52]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[52]]$timestamp
# [1] "2019100100"
#
# $`12_Years_a_Slave_(film)`[[52]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[52]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[52]]$views
# [1] 35006
#
#
# $`12_Years_a_Slave_(film)`[[53]]
# $`12_Years_a_Slave_(film)`[[53]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[53]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[53]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[53]]$timestamp
# [1] "2019110100"
#
# $`12_Years_a_Slave_(film)`[[53]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[53]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[53]]$views
# [1] 36960
#
#
# $`12_Years_a_Slave_(film)`[[54]]
# $`12_Years_a_Slave_(film)`[[54]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[54]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[54]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[54]]$timestamp
# [1] "2019120100"
#
# $`12_Years_a_Slave_(film)`[[54]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[54]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[54]]$views
# [1] 34577
#
#
# $`12_Years_a_Slave_(film)`[[55]]
# $`12_Years_a_Slave_(film)`[[55]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[55]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[55]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[55]]$timestamp
# [1] "2020010100"
#
# $`12_Years_a_Slave_(film)`[[55]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[55]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[55]]$views
# [1] 39842
#
#
# $`12_Years_a_Slave_(film)`[[56]]
# $`12_Years_a_Slave_(film)`[[56]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[56]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[56]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[56]]$timestamp
# [1] "2020020100"
#
# $`12_Years_a_Slave_(film)`[[56]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[56]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[56]]$views
# [1] 54434
#
#
# $`12_Years_a_Slave_(film)`[[57]]
# $`12_Years_a_Slave_(film)`[[57]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[57]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[57]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[57]]$timestamp
# [1] "2020030100"
#
# $`12_Years_a_Slave_(film)`[[57]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[57]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[57]]$views
# [1] 37975
#
#
# $`12_Years_a_Slave_(film)`[[58]]
# $`12_Years_a_Slave_(film)`[[58]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[58]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[58]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[58]]$timestamp
# [1] "2020040100"
#
# $`12_Years_a_Slave_(film)`[[58]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[58]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[58]]$views
# [1] 57217
#
#
# $`12_Years_a_Slave_(film)`[[59]]
# $`12_Years_a_Slave_(film)`[[59]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[59]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[59]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[59]]$timestamp
# [1] "2020050100"
#
# $`12_Years_a_Slave_(film)`[[59]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[59]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[59]]$views
# [1] 46425
#
#
# $`12_Years_a_Slave_(film)`[[60]]
# $`12_Years_a_Slave_(film)`[[60]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[60]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[60]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[60]]$timestamp
# [1] "2020060100"
#
# $`12_Years_a_Slave_(film)`[[60]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[60]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[60]]$views
# [1] 75356
#
#
# $`12_Years_a_Slave_(film)`[[61]]
# $`12_Years_a_Slave_(film)`[[61]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[61]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[61]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[61]]$timestamp
# [1] "2020070100"
#
# $`12_Years_a_Slave_(film)`[[61]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[61]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[61]]$views
# [1] 41722
#
#
# $`12_Years_a_Slave_(film)`[[62]]
# $`12_Years_a_Slave_(film)`[[62]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[62]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[62]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[62]]$timestamp
# [1] "2020080100"
#
# $`12_Years_a_Slave_(film)`[[62]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[62]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[62]]$views
# [1] 35035
#
#
# $`12_Years_a_Slave_(film)`[[63]]
# $`12_Years_a_Slave_(film)`[[63]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[63]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[63]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[63]]$timestamp
# [1] "2020090100"
#
# $`12_Years_a_Slave_(film)`[[63]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[63]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[63]]$views
# [1] 37000
#
#
# $`12_Years_a_Slave_(film)`[[64]]
# $`12_Years_a_Slave_(film)`[[64]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[64]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[64]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[64]]$timestamp
# [1] "2020100100"
#
# $`12_Years_a_Slave_(film)`[[64]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[64]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[64]]$views
# [1] 46763
#
#
# $`12_Years_a_Slave_(film)`[[65]]
# $`12_Years_a_Slave_(film)`[[65]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[65]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[65]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[65]]$timestamp
# [1] "2020110100"
#
# $`12_Years_a_Slave_(film)`[[65]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[65]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[65]]$views
# [1] 44792
#
#
# $`12_Years_a_Slave_(film)`[[66]]
# $`12_Years_a_Slave_(film)`[[66]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[66]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[66]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[66]]$timestamp
# [1] "2020120100"
#
# $`12_Years_a_Slave_(film)`[[66]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[66]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[66]]$views
# [1] 38230
#
#
# $`12_Years_a_Slave_(film)`[[67]]
# $`12_Years_a_Slave_(film)`[[67]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[67]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[67]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[67]]$timestamp
# [1] "2021010100"
#
# $`12_Years_a_Slave_(film)`[[67]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[67]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[67]]$views
# [1] 35887
#
#
# $`12_Years_a_Slave_(film)`[[68]]
# $`12_Years_a_Slave_(film)`[[68]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[68]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[68]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[68]]$timestamp
# [1] "2021020100"
#
# $`12_Years_a_Slave_(film)`[[68]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[68]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[68]]$views
# [1] 33294
#
#
# $`12_Years_a_Slave_(film)`[[69]]
# $`12_Years_a_Slave_(film)`[[69]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[69]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[69]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[69]]$timestamp
# [1] "2021030100"
#
# $`12_Years_a_Slave_(film)`[[69]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[69]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[69]]$views
# [1] 40472
#
#
# $`12_Years_a_Slave_(film)`[[70]]
# $`12_Years_a_Slave_(film)`[[70]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[70]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[70]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[70]]$timestamp
# [1] "2021040100"
#
# $`12_Years_a_Slave_(film)`[[70]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[70]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[70]]$views
# [1] 37150
#
#
# $`12_Years_a_Slave_(film)`[[71]]
# $`12_Years_a_Slave_(film)`[[71]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[71]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[71]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[71]]$timestamp
# [1] "2021050100"
#
# $`12_Years_a_Slave_(film)`[[71]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[71]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[71]]$views
# [1] 30885
#
#
# $`12_Years_a_Slave_(film)`[[72]]
# $`12_Years_a_Slave_(film)`[[72]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[72]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[72]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[72]]$timestamp
# [1] "2021060100"
#
# $`12_Years_a_Slave_(film)`[[72]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[72]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[72]]$views
# [1] 35283
#
#
# $`12_Years_a_Slave_(film)`[[73]]
# $`12_Years_a_Slave_(film)`[[73]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[73]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[73]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[73]]$timestamp
# [1] "2021070100"
#
# $`12_Years_a_Slave_(film)`[[73]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[73]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[73]]$views
# [1] 25193
#
#
# $`12_Years_a_Slave_(film)`[[74]]
# $`12_Years_a_Slave_(film)`[[74]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[74]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[74]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[74]]$timestamp
# [1] "2021080100"
#
# $`12_Years_a_Slave_(film)`[[74]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[74]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[74]]$views
# [1] 24627
#
#
# $`12_Years_a_Slave_(film)`[[75]]
# $`12_Years_a_Slave_(film)`[[75]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[75]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[75]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[75]]$timestamp
# [1] "2021090100"
#
# $`12_Years_a_Slave_(film)`[[75]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[75]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[75]]$views
# [1] 30659
#
#
# $`12_Years_a_Slave_(film)`[[76]]
# $`12_Years_a_Slave_(film)`[[76]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[76]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[76]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[76]]$timestamp
# [1] "2021100100"
#
# $`12_Years_a_Slave_(film)`[[76]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[76]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[76]]$views
# [1] 32259
#
#
# $`12_Years_a_Slave_(film)`[[77]]
# $`12_Years_a_Slave_(film)`[[77]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[77]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[77]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[77]]$timestamp
# [1] "2021110100"
#
# $`12_Years_a_Slave_(film)`[[77]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[77]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[77]]$views
# [1] 26102
#
#
# $`12_Years_a_Slave_(film)`[[78]]
# $`12_Years_a_Slave_(film)`[[78]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[78]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[78]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[78]]$timestamp
# [1] "2021120100"
#
# $`12_Years_a_Slave_(film)`[[78]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[78]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[78]]$views
# [1] 22719
#
#
# $`12_Years_a_Slave_(film)`[[79]]
# $`12_Years_a_Slave_(film)`[[79]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[79]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[79]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[79]]$timestamp
# [1] "2022010100"
#
# $`12_Years_a_Slave_(film)`[[79]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[79]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[79]]$views
# [1] 26483
#
#
# $`12_Years_a_Slave_(film)`[[80]]
# $`12_Years_a_Slave_(film)`[[80]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[80]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[80]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[80]]$timestamp
# [1] "2022020100"
#
# $`12_Years_a_Slave_(film)`[[80]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[80]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[80]]$views
# [1] 31639
#
#
# $`12_Years_a_Slave_(film)`[[81]]
# $`12_Years_a_Slave_(film)`[[81]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[81]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[81]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[81]]$timestamp
# [1] "2022030100"
#
# $`12_Years_a_Slave_(film)`[[81]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[81]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[81]]$views
# [1] 36281
#
#
# $`12_Years_a_Slave_(film)`[[82]]
# $`12_Years_a_Slave_(film)`[[82]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[82]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[82]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[82]]$timestamp
# [1] "2022040100"
#
# $`12_Years_a_Slave_(film)`[[82]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[82]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[82]]$views
# [1] 27236
#
#
# $`12_Years_a_Slave_(film)`[[83]]
# $`12_Years_a_Slave_(film)`[[83]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[83]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[83]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[83]]$timestamp
# [1] "2022050100"
#
# $`12_Years_a_Slave_(film)`[[83]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[83]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[83]]$views
# [1] 22849
#
#
# $`12_Years_a_Slave_(film)`[[84]]
# $`12_Years_a_Slave_(film)`[[84]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[84]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[84]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[84]]$timestamp
# [1] "2022060100"
#
# $`12_Years_a_Slave_(film)`[[84]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[84]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[84]]$views
# [1] 24650
#
#
# $`12_Years_a_Slave_(film)`[[85]]
# $`12_Years_a_Slave_(film)`[[85]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[85]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[85]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[85]]$timestamp
# [1] "2022070100"
#
# $`12_Years_a_Slave_(film)`[[85]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[85]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[85]]$views
# [1] 18646
#
#
# $`12_Years_a_Slave_(film)`[[86]]
# $`12_Years_a_Slave_(film)`[[86]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[86]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[86]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[86]]$timestamp
# [1] "2022080100"
#
# $`12_Years_a_Slave_(film)`[[86]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[86]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[86]]$views
# [1] 19386
#
#
# $`12_Years_a_Slave_(film)`[[87]]
# $`12_Years_a_Slave_(film)`[[87]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[87]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[87]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[87]]$timestamp
# [1] "2022090100"
#
# $`12_Years_a_Slave_(film)`[[87]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[87]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[87]]$views
# [1] 19913
#
#
# $`12_Years_a_Slave_(film)`[[88]]
# $`12_Years_a_Slave_(film)`[[88]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[88]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[88]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[88]]$timestamp
# [1] "2022100100"
#
# $`12_Years_a_Slave_(film)`[[88]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[88]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[88]]$views
# [1] 21353
#
#
# $`12_Years_a_Slave_(film)`[[89]]
# $`12_Years_a_Slave_(film)`[[89]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[89]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[89]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[89]]$timestamp
# [1] "2022110100"
#
# $`12_Years_a_Slave_(film)`[[89]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[89]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[89]]$views
# [1] 23880
#
#
# $`12_Years_a_Slave_(film)`[[90]]
# $`12_Years_a_Slave_(film)`[[90]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[90]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[90]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[90]]$timestamp
# [1] "2022120100"
#
# $`12_Years_a_Slave_(film)`[[90]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[90]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[90]]$views
# [1] 22273
#
#
# $`12_Years_a_Slave_(film)`[[91]]
# $`12_Years_a_Slave_(film)`[[91]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[91]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[91]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[91]]$timestamp
# [1] "2023010100"
#
# $`12_Years_a_Slave_(film)`[[91]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[91]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[91]]$views
# [1] 27933
#
#
# $`12_Years_a_Slave_(film)`[[92]]
# $`12_Years_a_Slave_(film)`[[92]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[92]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[92]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[92]]$timestamp
# [1] "2023020100"
#
# $`12_Years_a_Slave_(film)`[[92]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[92]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[92]]$views
# [1] 23454
#
#
# $`12_Years_a_Slave_(film)`[[93]]
# $`12_Years_a_Slave_(film)`[[93]]$project
# [1] "en.wikipedia"
#
# $`12_Years_a_Slave_(film)`[[93]]$article
# [1] "12_Years_a_Slave_(film)"
#
# $`12_Years_a_Slave_(film)`[[93]]$granularity
# [1] "monthly"
#
# $`12_Years_a_Slave_(film)`[[93]]$timestamp
# [1] "2023030100"
#
# $`12_Years_a_Slave_(film)`[[93]]$access
# [1] "desktop"
#
# $`12_Years_a_Slave_(film)`[[93]]$agent
# [1] "user"
#
# $`12_Years_a_Slave_(film)`[[93]]$views
# [1] 30942
#
#
#
# $`1917_(2019_film)`
# $`1917_(2019_film)`[[1]]
# $`1917_(2019_film)`[[1]]$project
# [1] "en.wikipedia"
#
# $`1917_(2019_film)`[[1]]$article
# [1] "1917_(2019_film)"
#
# $`1917_(2019_film)`[[1]]$granularity
# [1] "monthly"
#
# $`1917_(2019_film)`[[1]]$timestamp
# [1] "2019030100"
#
# $`1917_(2019_film)`[[1]]$access
# [1] "desktop"
#
# $`1917_(2019_film)`[[1]]$agent
# [1] "user"
#
# $`1917_(2019_film)`[[1]]$views
# [1] 601
#
#
# $`1917_(2019_film)`[[2]]
# $`1917_(2019_film)`[[2]]$project
# [1] "en.wikipedia"
#
# $`1917_(2019_film)`[[2]]$article
# [1] "1917_(2019_film)"
#
# $`1917_(2019_film)`[[2]]$granularity
# [1] "monthly"
#
# $`1917_(2019_film)`[[2]]$timestamp
# [1] "2019040100"
#
# $`1917_(2019_film)`[[2]]$access
# [1] "desktop"
#
# $`1917_(2019_film)`[[2]]$agent
# [1] "user"
#
# $`1917_(2019_film)`[[2]]$views
# [1] 25787
#
#
# $`1917_(2019_film)`[[3]]
# $`1917_(2019_film)`[[3]]$project
# [1] "en.wikipedia"
#
# $`1917_(2019_film)`[[3]]$article
# [1] "1917_(2019_film)"
#
# $`1917_(2019_film)`[[3]]$granularity
# [1] "monthly"
#
# $`1917_(2019_film)`[[3]]$timestamp
# [1] "2019050100"
#
# $`1917_(2019_film)`[[3]]$access
# [1] "desktop"
#
# $`1917_(2019_film)`[[3]]$agent
# [1] "user"
#
# $`1917_(2019_film)`[[3]]$views
# [1] 24608
#
#
# $`1917_(2019_film)`[[4]]
# $`1917_(2019_film)`[[4]]$project
# [1] "en.wikipedia"
#
# $`1917_(2019_film)`[[4]]$article
# [1] "1917_(2019_film)"
#
# $`1917_(2019_film)`[[4]]$granularity
# [1] "monthly"
#
# $`1917_(2019_film)`[[4]]$timestamp
# [1] "2019060100"
#
# $`1917_(2019_film)`[[4]]$access
# [1] "desktop"
#
# $`1917_(2019_film)`[[4]]$agent
# [1] "user"
#
# $`1917_(2019_film)`[[4]]$views
# [1] 27937
#
#
# $`1917_(2019_film)`[[5]]
# $`1917_(2019_film)`[[5]]$project
# [1] "en.wikipedia"
#
# $`1917_(2019_film)`[[5]]$article
# [1] "1917_(2019_film)"
#
# $`1917_(2019_film)`[[5]]$granularity
# [1] "monthly"
#
# $`1917_(2019_film)`[[5]]$timestamp
# [1] "2019070100"
#
# $`1917_(2019_film)`[[5]]$access
# [1] "desktop"
#
# $`1917_(2019_film)`[[5]]$agent
# [1] "user"
#
# $`1917_(2019_film)`[[5]]$views
# [1] 24786
#
#
# $`1917_(2019_film)`[[6]]
# $`1917_(2019_film)`[[6]]$project
# [1] "en.wikipedia"
#
# $`1917_(2019_film)`[[6]]$article
# [1] "1917_(2019_film)"
#
# $`1917_(2019_film)`[[6]]$granularity
# [1] "monthly"
#
# $`1917_(2019_film)`[[6]]$timestamp
# [1] "2019080100"
#
# $`1917_(2019_film)`[[6]]$access
# [1] "desktop"
#
# $`1917_(2019_film)`[[6]]$agent
# [1] "user"
#
# $`1917_(2019_film)`[[6]]$views
# [1] 95236
#
#
# $`1917_(2019_film)`[[7]]
# $`1917_(2019_film)`[[7]]$project
# [1] "en.wikipedia"
#
# $`1917_(2019_film)`[[7]]$article
# [1] "1917_(2019_film)"
#
# $`1917_(2019_film)`[[7]]$granularity
# [1] "monthly"
#
# $`1917_(2019_film)`[[7]]$timestamp
# [1] "2019090100"
#
# $`1917_(2019_film)`[[7]]$access
# [1] "desktop"
#
# $`1917_(2019_film)`[[7]]$agent
# [1] "user"
#
# $`1917_(2019_film)`[[7]]$views
# [1] 37866
#
#
# $`1917_(2019_film)`[[8]]
# $`1917_(2019_film)`[[8]]$project
# [1] "en.wikipedia"
#
# $`1917_(2019_film)`[[8]]$article
# [1] "1917_(2019_film)"
#
# $`1917_(2019_film)`[[8]]$granularity
# [1] "monthly"
#
# $`1917_(2019_film)`[[8]]$timestamp
# [1] "2019100100"
#
# $`1917_(2019_film)`[[8]]$access
# [1] "desktop"
#
# $`1917_(2019_film)`[[8]]$agent
# [1] "user"
#
# $`1917_(2019_film)`[[8]]$views
# [1] 93523
#
#
# $`1917_(2019_film)`[[9]]
# $`1917_(2019_film)`[[9]]$project
# [1] "en.wikipedia"
#
# $`1917_(2019_film)`[[9]]$article
# [1] "1917_(2019_film)"
#
# $`1917_(2019_film)`[[9]]$granularity
# [1] "monthly"
#
# $`1917_(2019_film)`[[9]]$timestamp
# [1] "2019110100"
#
# $`1917_(2019_film)`[[9]]$access
# [1] "desktop"
#
# $`1917_(2019_film)`[[9]]$agent
# [1] "user"
#
# $`1917_(2019_film)`[[9]]$views
# [1] 99940
#
#
# $`1917_(2019_film)`[[10]]
# $`1917_(2019_film)`[[10]]$project
# [1] "en.wikipedia"
#
# $`1917_(2019_film)`[[10]]$article
# [1] "1917_(2019_film)"
#
# $`1917_(2019_film)`[[10]]$granularity
# [1] "monthly"
#
# $`1917_(2019_film)`[[10]]$timestamp
# [1] "2019120100"
#
# $`1917_(2019_film)`[[10]]$access
# [1] "desktop"
#
# $`1917_(2019_film)`[[10]]$agent
# [1] "user"
#
# $`1917_(2019_film)`[[10]]$views
# [1] 266149
#
#
# $`1917_(2019_film)`[[11]]
# $`1917_(2019_film)`[[11]]$project
# [1] "en.wikipedia"
#
# $`1917_(2019_film)`[[11]]$article
# [1] "1917_(2019_film)"
#
# $`1917_(2019_film)`[[11]]$granularity
# [1] "monthly"
#
# $`1917_(2019_film)`[[11]]$timestamp
# [1] "2020010100"
#
# $`1917_(2019_film)`[[11]]$access
# [1] "desktop"
#
# $`1917_(2019_film)`[[11]]$agent
# [1] "user"
#
# $`1917_(2019_film)`[[11]]$views
# [1] 1567798
#
#
# $`1917_(2019_film)`[[12]]
# $`1917_(2019_film)`[[12]]$project
# [1] "en.wikipedia"
#
# $`1917_(2019_film)`[[12]]$article
# [1] "1917_(2019_film)"
#
# $`1917_(2019_film)`[[12]]$granularity
# [1] "monthly"
#
# $`1917_(2019_film)`[[12]]$timestamp
# [1] "2020020100"
#
# $`1917_(2019_film)`[[12]]$access
# [1] "desktop"
#
# $`1917_(2019_film)`[[12]]$agent
# [1] "user"
#
# $`1917_(2019_film)`[[12]]$views
# [1] 622928
#
#
# $`1917_(2019_film)`[[13]]
# $`1917_(2019_film)`[[13]]$project
# [1] "en.wikipedia"
#
# $`1917_(2019_film)`[[13]]$article
# [1] "1917_(2019_film)"
#
# $`1917_(2019_film)`[[13]]$granularity
# [1] "monthly"
#
# $`1917_(2019_film)`[[13]]$timestamp
# [1] "2020030100"
#
# $`1917_(2019_film)`[[13]]$access
# [1] "desktop"
#
# $`1917_(2019_film)`[[13]]$agent
# [1] "user"
#
# $`1917_(2019_film)`[[13]]$views
# [1] 274004
#
#
# $`1917_(2019_film)`[[14]]
# $`1917_(2019_film)`[[14]]$project
# [1] "en.wikipedia"
#
# $`1917_(2019_film)`[[14]]$article
# [1] "1917_(2019_film)"
#
# $`1917_(2019_film)`[[14]]$granularity
# [1] "monthly"
#
# $`1917_(2019_film)`[[14]]$timestamp
# [1] "2020040100"
#
# $`1917_(2019_film)`[[14]]$access
# [1] "desktop"
#
# $`1917_(2019_film)`[[14]]$agent
# [1] "user"
#
# $`1917_(2019_film)`[[14]]$views
# [1] 253772
#
#
# $`1917_(2019_film)`[[15]]
# $`1917_(2019_film)`[[15]]$project
# [1] "en.wikipedia"
#
# $`1917_(2019_film)`[[15]]$article
# [1] "1917_(2019_film)"
#
# $`1917_(2019_film)`[[15]]$granularity
# [1] "monthly"
#
# $`1917_(2019_film)`[[15]]$timestamp
# [1] "2020050100"
#
# $`1917_(2019_film)`[[15]]$access
# [1] "desktop"
#
# $`1917_(2019_film)`[[15]]$agent
# [1] "user"
#
# $`1917_(2019_film)`[[15]]$views
# [1] 226542
#
#
# $`1917_(2019_film)`[[16]]
# $`1917_(2019_film)`[[16]]$project
# [1] "en.wikipedia"
#
# $`1917_(2019_film)`[[16]]$article
# [1] "1917_(2019_film)"
#
# $`1917_(2019_film)`[[16]]$granularity
# [1] "monthly"
#
# $`1917_(2019_film)`[[16]]$timestamp
# [1] "2020060100"
#
# $`1917_(2019_film)`[[16]]$access
# [1] "desktop"
#
# $`1917_(2019_film)`[[16]]$agent
# [1] "user"
#
# $`1917_(2019_film)`[[16]]$views
# [1] 135320
#
#
# $`1917_(2019_film)`[[17]]
# $`1917_(2019_film)`[[17]]$project
# [1] "en.wikipedia"
#
# $`1917_(2019_film)`[[17]]$article
# [1] "1917_(2019_film)"
#
# $`1917_(2019_film)`[[17]]$granularity
# [1] "monthly"
#
# $`1917_(2019_film)`[[17]]$timestamp
# [1] "2020070100"
#
# $`1917_(2019_film)`[[17]]$access
# [1] "desktop"
#
# $`1917_(2019_film)`[[17]]$agent
# [1] "user"
#
# $`1917_(2019_film)`[[17]]$views
# [1] 95816
#
#
# $`1917_(2019_film)`[[18]]
# $`1917_(2019_film)`[[18]]$project
# [1] "en.wikipedia"
#
# $`1917_(2019_film)`[[18]]$article
# [1] "1917_(2019_film)"
#
# $`1917_(2019_film)`[[18]]$granularity
# [1] "monthly"
#
# $`1917_(2019_film)`[[18]]$timestamp
# [1] "2020080100"
#
# $`1917_(2019_film)`[[18]]$access
# [1] "desktop"
#
# ...
# [1] "user"
#
# $`49th_Parallel_(film)`[[55]]$views
# [1] 1242
#
#
# $`49th_Parallel_(film)`[[56]]
# $`49th_Parallel_(film)`[[56]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[56]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[56]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[56]]$timestamp
# [1] "2020020100"
#
# $`49th_Parallel_(film)`[[56]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[56]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[56]]$views
# [1] 5579
#
#
# $`49th_Parallel_(film)`[[57]]
# $`49th_Parallel_(film)`[[57]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[57]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[57]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[57]]$timestamp
# [1] "2020030100"
#
# $`49th_Parallel_(film)`[[57]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[57]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[57]]$views
# [1] 1671
#
#
# $`49th_Parallel_(film)`[[58]]
# $`49th_Parallel_(film)`[[58]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[58]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[58]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[58]]$timestamp
# [1] "2020040100"
#
# $`49th_Parallel_(film)`[[58]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[58]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[58]]$views
# [1] 2016
#
#
# $`49th_Parallel_(film)`[[59]]
# $`49th_Parallel_(film)`[[59]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[59]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[59]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[59]]$timestamp
# [1] "2020050100"
#
# $`49th_Parallel_(film)`[[59]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[59]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[59]]$views
# [1] 2162
#
#
# $`49th_Parallel_(film)`[[60]]
# $`49th_Parallel_(film)`[[60]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[60]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[60]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[60]]$timestamp
# [1] "2020060100"
#
# $`49th_Parallel_(film)`[[60]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[60]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[60]]$views
# [1] 4568
#
#
# $`49th_Parallel_(film)`[[61]]
# $`49th_Parallel_(film)`[[61]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[61]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[61]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[61]]$timestamp
# [1] "2020070100"
#
# $`49th_Parallel_(film)`[[61]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[61]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[61]]$views
# [1] 1703
#
#
# $`49th_Parallel_(film)`[[62]]
# $`49th_Parallel_(film)`[[62]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[62]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[62]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[62]]$timestamp
# [1] "2020080100"
#
# $`49th_Parallel_(film)`[[62]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[62]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[62]]$views
# [1] 1729
#
#
# $`49th_Parallel_(film)`[[63]]
# $`49th_Parallel_(film)`[[63]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[63]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[63]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[63]]$timestamp
# [1] "2020090100"
#
# $`49th_Parallel_(film)`[[63]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[63]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[63]]$views
# [1] 3898
#
#
# $`49th_Parallel_(film)`[[64]]
# $`49th_Parallel_(film)`[[64]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[64]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[64]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[64]]$timestamp
# [1] "2020100100"
#
# $`49th_Parallel_(film)`[[64]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[64]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[64]]$views
# [1] 1890
#
#
# $`49th_Parallel_(film)`[[65]]
# $`49th_Parallel_(film)`[[65]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[65]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[65]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[65]]$timestamp
# [1] "2020110100"
#
# $`49th_Parallel_(film)`[[65]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[65]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[65]]$views
# [1] 1534
#
#
# $`49th_Parallel_(film)`[[66]]
# $`49th_Parallel_(film)`[[66]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[66]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[66]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[66]]$timestamp
# [1] "2020120100"
#
# $`49th_Parallel_(film)`[[66]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[66]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[66]]$views
# [1] 4431
#
#
# $`49th_Parallel_(film)`[[67]]
# $`49th_Parallel_(film)`[[67]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[67]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[67]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[67]]$timestamp
# [1] "2021010100"
#
# $`49th_Parallel_(film)`[[67]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[67]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[67]]$views
# [1] 2050
#
#
# $`49th_Parallel_(film)`[[68]]
# $`49th_Parallel_(film)`[[68]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[68]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[68]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[68]]$timestamp
# [1] "2021020100"
#
# $`49th_Parallel_(film)`[[68]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[68]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[68]]$views
# [1] 4275
#
#
# $`49th_Parallel_(film)`[[69]]
# $`49th_Parallel_(film)`[[69]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[69]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[69]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[69]]$timestamp
# [1] "2021030100"
#
# $`49th_Parallel_(film)`[[69]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[69]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[69]]$views
# [1] 1730
#
#
# $`49th_Parallel_(film)`[[70]]
# $`49th_Parallel_(film)`[[70]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[70]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[70]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[70]]$timestamp
# [1] "2021040100"
#
# $`49th_Parallel_(film)`[[70]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[70]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[70]]$views
# [1] 1921
#
#
# $`49th_Parallel_(film)`[[71]]
# $`49th_Parallel_(film)`[[71]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[71]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[71]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[71]]$timestamp
# [1] "2021050100"
#
# $`49th_Parallel_(film)`[[71]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[71]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[71]]$views
# [1] 1914
#
#
# $`49th_Parallel_(film)`[[72]]
# $`49th_Parallel_(film)`[[72]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[72]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[72]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[72]]$timestamp
# [1] "2021060100"
#
# $`49th_Parallel_(film)`[[72]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[72]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[72]]$views
# [1] 3249
#
#
# $`49th_Parallel_(film)`[[73]]
# $`49th_Parallel_(film)`[[73]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[73]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[73]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[73]]$timestamp
# [1] "2021070100"
#
# $`49th_Parallel_(film)`[[73]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[73]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[73]]$views
# [1] 1458
#
#
# $`49th_Parallel_(film)`[[74]]
# $`49th_Parallel_(film)`[[74]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[74]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[74]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[74]]$timestamp
# [1] "2021080100"
#
# $`49th_Parallel_(film)`[[74]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[74]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[74]]$views
# [1] 1428
#
#
# $`49th_Parallel_(film)`[[75]]
# $`49th_Parallel_(film)`[[75]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[75]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[75]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[75]]$timestamp
# [1] "2021090100"
#
# $`49th_Parallel_(film)`[[75]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[75]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[75]]$views
# [1] 1305
#
#
# $`49th_Parallel_(film)`[[76]]
# $`49th_Parallel_(film)`[[76]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[76]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[76]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[76]]$timestamp
# [1] "2021100100"
#
# $`49th_Parallel_(film)`[[76]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[76]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[76]]$views
# [1] 1760
#
#
# $`49th_Parallel_(film)`[[77]]
# $`49th_Parallel_(film)`[[77]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[77]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[77]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[77]]$timestamp
# [1] "2021110100"
#
# $`49th_Parallel_(film)`[[77]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[77]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[77]]$views
# [1] 1579
#
#
# $`49th_Parallel_(film)`[[78]]
# $`49th_Parallel_(film)`[[78]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[78]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[78]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[78]]$timestamp
# [1] "2021120100"
#
# $`49th_Parallel_(film)`[[78]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[78]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[78]]$views
# [1] 3717
#
#
# $`49th_Parallel_(film)`[[79]]
# $`49th_Parallel_(film)`[[79]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[79]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[79]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[79]]$timestamp
# [1] "2022010100"
#
# $`49th_Parallel_(film)`[[79]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[79]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[79]]$views
# [1] 2056
#
#
# $`49th_Parallel_(film)`[[80]]
# $`49th_Parallel_(film)`[[80]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[80]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[80]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[80]]$timestamp
# [1] "2022020100"
#
# $`49th_Parallel_(film)`[[80]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[80]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[80]]$views
# [1] 2126
#
#
# $`49th_Parallel_(film)`[[81]]
# $`49th_Parallel_(film)`[[81]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[81]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[81]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[81]]$timestamp
# [1] "2022030100"
#
# $`49th_Parallel_(film)`[[81]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[81]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[81]]$views
# [1] 8217
#
#
# $`49th_Parallel_(film)`[[82]]
# $`49th_Parallel_(film)`[[82]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[82]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[82]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[82]]$timestamp
# [1] "2022040100"
#
# $`49th_Parallel_(film)`[[82]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[82]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[82]]$views
# [1] 2466
#
#
# $`49th_Parallel_(film)`[[83]]
# $`49th_Parallel_(film)`[[83]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[83]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[83]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[83]]$timestamp
# [1] "2022050100"
#
# $`49th_Parallel_(film)`[[83]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[83]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[83]]$views
# [1] 1945
#
#
# $`49th_Parallel_(film)`[[84]]
# $`49th_Parallel_(film)`[[84]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[84]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[84]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[84]]$timestamp
# [1] "2022060100"
#
# $`49th_Parallel_(film)`[[84]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[84]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[84]]$views
# [1] 1656
#
#
# $`49th_Parallel_(film)`[[85]]
# $`49th_Parallel_(film)`[[85]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[85]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[85]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[85]]$timestamp
# [1] "2022070100"
#
# $`49th_Parallel_(film)`[[85]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[85]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[85]]$views
# [1] 1484
#
#
# $`49th_Parallel_(film)`[[86]]
# $`49th_Parallel_(film)`[[86]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[86]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[86]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[86]]$timestamp
# [1] "2022080100"
#
# $`49th_Parallel_(film)`[[86]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[86]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[86]]$views
# [1] 1614
#
#
# $`49th_Parallel_(film)`[[87]]
# $`49th_Parallel_(film)`[[87]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[87]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[87]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[87]]$timestamp
# [1] "2022090100"
#
# $`49th_Parallel_(film)`[[87]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[87]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[87]]$views
# [1] 1621
#
#
# $`49th_Parallel_(film)`[[88]]
# $`49th_Parallel_(film)`[[88]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[88]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[88]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[88]]$timestamp
# [1] "2022100100"
#
# $`49th_Parallel_(film)`[[88]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[88]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[88]]$views
# [1] 1871
#
#
# $`49th_Parallel_(film)`[[89]]
# $`49th_Parallel_(film)`[[89]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[89]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[89]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[89]]$timestamp
# [1] "2022110100"
#
# $`49th_Parallel_(film)`[[89]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[89]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[89]]$views
# [1] 1835
#
#
# $`49th_Parallel_(film)`[[90]]
# $`49th_Parallel_(film)`[[90]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[90]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[90]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[90]]$timestamp
# [1] "2022120100"
#
# $`49th_Parallel_(film)`[[90]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[90]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[90]]$views
# [1] 8030
#
#
# $`49th_Parallel_(film)`[[91]]
# $`49th_Parallel_(film)`[[91]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[91]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[91]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[91]]$timestamp
# [1] "2023010100"
#
# $`49th_Parallel_(film)`[[91]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[91]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[91]]$views
# [1] 2599
#
#
# $`49th_Parallel_(film)`[[92]]
# $`49th_Parallel_(film)`[[92]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[92]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[92]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[92]]$timestamp
# [1] "2023020100"
#
# $`49th_Parallel_(film)`[[92]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[92]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[92]]$views
# [1] 2068
#
#
# $`49th_Parallel_(film)`[[93]]
# $`49th_Parallel_(film)`[[93]]$project
# [1] "en.wikipedia"
#
# $`49th_Parallel_(film)`[[93]]$article
# [1] "49th_Parallel_(film)"
#
# $`49th_Parallel_(film)`[[93]]$granularity
# [1] "monthly"
#
# $`49th_Parallel_(film)`[[93]]$timestamp
# [1] "2023030100"
#
# $`49th_Parallel_(film)`[[93]]$access
# [1] "mobile-web"
#
# $`49th_Parallel_(film)`[[93]]$agent
# [1] "user"
#
# $`49th_Parallel_(film)`[[93]]$views
# [1] 4019

# %% [markdown]
# ## Combining and Refining Data as DataFrames
#
# The below two cells convert our three list objects into DataFrames, and then use DataFrame operations to transform and aggregate them to get our desired results (as described in the header)

# %%
##This function converts lists structured like the outputs of he
##previous cell into R DataFrames. 
##This will make it possible to combine their view counts
##using a join operation

convert_json_to_df <- function(big_json) {
  result <- data.frame()
  for(film in big_json){
    film_df <- data.frame(t(sapply(film,c))) #do.call(rbind.data.frame, film)
    if(nrow(result) < 1){
      result <- film_df
    }
    else {
      result <- rbind(result, film_df)
    }
    
  }
  return(result)
}

##These lines use the previous function on
##our three lists.
desktop_df <- convert_json_to_df(desktop)
mob_web_df <- convert_json_to_df(mob_web)
mob_app_df <- convert_json_to_df(mob_app)

# %%
##This function joins two dataframes structured
##like the results of the previous cell and produces
##a new one that sums up the views for each month/article
##combination in the original two DFs
sum_views_in_DFs <- function(df1, df2){
  merge_cols <- c("project", "article", "granularity", "timestamp", "agent")
  combined_df <- merge(x=df1,y=df2,by=merge_cols,all=TRUE)
  combined_df$views <- as.numeric(combined_df$views.x) + as.numeric(combined_df$views.y)
  combined_df$access <- NULL
  combined_df$access.x <- NULL
  combined_df$access.y <- NULL
  combined_df$views.x <- NULL
  combined_df$views.y <- NULL 
  return(combined_df)
}

##These lines use the previous function to obtain the
##mobile and cumulative data collections in dataframe format
all_mob_df <- sum_views_in_DFs(mob_app_df, mob_web_df)
cumulative_df <- sum_views_in_DFs(all_mob_df, desktop_df)

##The access field is dropped in the desktop DF to make its 
##schema consistent with those of the cumulative and mobile DFs.
desktop_df$access <- NULL

head(desktop_df)
# Out:
#   project      article                 granularity timestamp  agent views
# 1 en.wikipedia 12_Years_a_Slave_(film) monthly     2015070100 user  62693
# 2 en.wikipedia 12_Years_a_Slave_(film) monthly     2015080100 user  58902
# 3 en.wikipedia 12_Years_a_Slave_(film) monthly     2015090100 user  59116
# 4 en.wikipedia 12_Years_a_Slave_(film) monthly     2015100100 user  65535
# 5 en.wikipedia 12_Years_a_Slave_(film) monthly     2015110100 user  66646
# 6 en.wikipedia 12_Years_a_Slave_(film) monthly     2015120100 user  71846

# %% [markdown]
# ## Converting Back and Exporting
#
# The below two cells convert our refined data back into List format so it can be dumped in JSON format for use in Step 3.

# %%
##This function convertis the DFs back into list objects
##that can be exported as JSON files
convert_df_to_json <- function(df){
  big_json <- list()
  film_names <- unique(df$article)
  for(film in film_names){
    df_subset <- df[df$article == film, ]
    rownames(df_subset) <- 1:nrow(df_subset)
    #json_subset <- as.list(split(df_subset, 1:nrow(df_subset)))
    json_subset <- vector("list",nrow(df_subset))
    for(rownum in 1:nrow(df_subset)){
      individual_json_object <- list()
      for(colname in colnames(df_subset)){
        individual_json_object[[colname]] <- df_subset[[rownum, colname]]
      }
      json_subset[[rownum]] <- individual_json_object
    }
    big_json[film] <- list(json_subset)
  }
  return(big_json)
}

##Here we use our last function to obtain our final results
desktop_json <- convert_df_to_json(desktop_df)
all_mob_json <- convert_df_to_json(all_mob_df)
cumulative_json <- convert_df_to_json(cumulative_df)

# %%
##calculating min and max timestamps for naming conventions
desktop_min_time <- min(unique(unlist(desktop_df$timestamp)))
desktop_max_time <- max(unique(unlist(desktop_df$timestamp)))
all_mob_min_time <- min(unique(unlist(all_mob_df$timestamp)))
all_mob_max_time <- max(unique(unlist(all_mob_df$timestamp)))
cumulative_min_time <- min(unique(unlist(cumulative_df$timestamp)))
cumulative_max_time <- max(unique(unlist(cumulative_df$timestamp)))

##Final part of data processing - dumping JSON
##to desired locations

refined_data_path <- "refined_data/"
all_mob_filepath <- paste0(refined_data_path, 
                              "academy_monthly_mobile_start",
                              substring(all_mob_min_time, 1, 6),
                              "-end",
                              substring(all_mob_max_time, 1, 6),
                              ".json")
cumulative_filepath <- paste0(refined_data_path, 
                              "academy_monthly_cumulative_start",
                              substring(cumulative_min_time, 1, 6),
                              "-end",
                              substring(cumulative_max_time, 1, 6),
                              ".json")
desktop_filepath <- paste0(refined_data_path, 
                              "academy_monthly_desktop_start",
                              substring(desktop_min_time, 1, 6),
                              "-end",
                              substring(desktop_max_time, 1, 6),
                              ".json")
write_json(desktop_json, desktop_filepath, auto_unbox = TRUE)
write_json(cumulative_json, cumulative_filepath, auto_unbox = TRUE)
write_json(all_mob_json, all_mob_filepath, auto_unbox = TRUE)
